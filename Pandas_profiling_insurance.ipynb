# %%
pip install pandas_profiling

# %%
import pandas as pd
import numpy as np
import pandas_profiling as pp

# %%
df = pd.read_csv('C:/Users/ppramanik2/Documents/Insurance_dataset_pradyumna.csv')

# %%
df.describe()
# Out:
#        Customer Identity  First Policy´s Year  Brithday Year  \
# count        10296.00000         10266.000000   10279.000000
# mean          5148.50000          1991.062634    1968.007783
# std           2972.34352           511.267913      19.709476
# min              1.00000          1974.000000    1028.000000
# 25%           2574.75000          1980.000000    1953.000000
# 50%           5148.50000          1986.000000    1968.000000
# 75%           7722.25000          1992.000000    1983.000000
# max          10296.00000         53784.000000    2001.000000
#
#        Gross Monthly Salary  Geographic Living Area  Has Children (Y=1)  \
# count          10260.000000            10295.000000        10275.000000
# mean            2506.667057                2.709859            0.706764
# std             1157.449634                1.266291            0.455268
# min              333.000000                1.000000            0.000000
# ...

# %%
pp.ProfileReport(df)
# Out:
# C:\Users\ppramanik2\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas_profiling\describe.py:404: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
# ...

# %%
d=pp.ProfileReport(df)
# Out:
# C:\Users\ppramanik2\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas_profiling\describe.py:404: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)

# %%
d.to_file('Insurance_pandas_profiling.html.html')
